# %% [markdown]
# <a href="https://colab.research.google.com/github/dSubhashini7/Plotting/blob/main/Copy_of_Copy_of_IMAGE_RESOURCING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# fADbBP.jpg  FISH.jpg  OpenCV.ipynb  sample_data

# %%
# !pip install opencv-python==3.4.2.16
# Out:
# ...
#      |████████████████████████████████| 25.0MB 1.6MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/FISH.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x721 at 0x7F87F06E5A20>

# %%
cv2.imwrite("COLORFULL FISH.jpg", image)
# Out:
# True

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
import numpy as np

# %%
canvas = np.ones((500, 500, 3), dtype="uint8")*255

# %%
black =(0, 0, 0)
cv2.line(canvas, (0,0), (400,400),black,3) 
cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F87E698EBE0>

# %%
yellow = (0,225,225)
cv2.rectangle(canvas, (150,100), (100,225), yellow,5)
cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F87E68FE9B0>

# %%
green = (0,255,0)
cv2.rectangle(canvas,(300,50), (425,125), green, -1)
cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F87E6916908>

# %%
canvas = np.zeros((500, 500, 3), dtype="uint8")

# %%
for i in range(0, 25):
	# randomly generate a radius size between 5 and 200, generate a random
	# color, and then pick a random point on our canvas where the circle
	# will be drawn
	radius = np.random.randint(5, high=300)
	color = np.random.randint(0, high=256, size = (3,)).tolist()
	pt = np.random.randint(0, high=400, size = (2,))


	cv2.circle(canvas, tuple(pt), radius, color, -1)


cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F87E68A3080>

# %% [markdown]
# **WRITING TEXT ON IMAGE**

# %%
image = cv2.imread("/content/COLORFULL FISH.jpg")
cv2.putText(image, 'COLORFULL FISH', (140,280), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 2.5, (0,225,225), 8)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x721 at 0x7F87E6916710>

# %% [markdown]
# **Translate**

# %%
import imutils

# %%
image = cv2.imread("/content/wallpaper.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBBC994A8>

# %%
shifted = imutils.translate(image, 100, -100)
cv2_imshow(shifted)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBAD10390>

# %% [markdown]
#  ** Rotate Image**

# %%
import imutils

# %%
rotated = imutils.rotate(image,180)
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBBC99588>

# %% [markdown]
# ** Crop Image **

# %%
crop = image[10:300, 10:300]
cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=RGB size=290x290 at 0x7F0BBBC99BA8>

# %% [markdown]
# ** Resize without aspect Ratio **

# %%
resized = cv2.resize(image, (500,500))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F0BBAD27FD0>

# %% [markdown]
# ** Resize with aspect Ratio **

# %%
resized = imutils.resize(image, width=500)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F0BBAD27898>

# %% [markdown]
# **FLIPPING**

# %%
flipped = cv2.flip(image, 1)
cv2_imshow(flipped)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBAD27898>

# %% [markdown]
# **BITWISE OPERATION**

# %%
rectangle = np.zeros((300, 300), dtype = "uint8")
cv2.rectangle(rectangle, (25, 25), (275, 275), 255, -1)
cv2_imshow(rectangle)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F0BBBC66DD8>

# %%
circle =np.zeros((300, 300), dtype = "uint8")
cv2.circle(circle, (150, 150), 150, 255, -1)
cv2_imshow(circle)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F0BBBC0A198>

# %%
bitwiseAnd = cv2.bitwise_and(rectangle, circle)
cv2_imshow(bitwiseAnd)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F0BBAD12908>

# %%
bitwiseOr = cv2.bitwise_or(rectangle, circle)
cv2_imshow(bitwiseOr)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F0BBAD12128>

# %%
bitwiseXor = cv2.bitwise_xor(rectangle, circle)
cv2_imshow(bitwiseXor)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F0BBAD12BA8>

# %%
bitwiseNot = cv2.bitwise_not(rectangle)
cv2_imshow(bitwiseNot)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F0BBAD12240>

# %% [markdown]
# **MASKING**

# %%
mask = np.zeros(image.shape[:2], dtype = "uint8")
cv2.rectangle(mask, (452, 243), (690, 590), 255, -1)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7F0BBAD271D0>

# %%
masked = cv2.bitwise_and(image, image, mask=mask)
cv2_imshow(masked)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBAD27898>

# %%
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.circle(mask, (585, 98), 50, 255, -1)
masked = cv2.bitwise_and(image, image, mask=mask)
cv2_imshow(mask)
cv2_imshow(masked)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7F0BBBC99278>
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBBC99908>

# %% [markdown]
# **Removing Noise in the images**

# %% [markdown]
# **Smoothing and Blurring**

# %% [markdown]
# Average Blurr

# %%
blurred = cv2.blur(image, (3,3))
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BBAD27FD0>

# %% [markdown]
# Gaussian Blur

# %%
blurred = cv2.GaussianBlur(image, (3,3), 0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F0BB94D6358>

# %% [markdown]
# **THRESHOLDING**
